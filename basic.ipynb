# %%
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
if c > 25:
    print("The sum is greater than 25.")
else:
    print("The sum is 25 or less.")
# Out:
# The sum is greater than 25.

# %%
while c > 0:
    print(f"Current value of c: {c}")
    c -= 5  # Decrease c by 5 in each iteration
# Out:
# Current value of c: 30
# Current value of c: 25
# Current value of c: 20
# Current value of c: 15
# Current value of c: 10
# Current value of c: 5

# %%
list1 = [1, 2, 3, 4, 5]
squared_list = [x**2 for x in list1]
print(squared_list)
# Out:
# [1, 4, 9, 16, 25]

# %%
#tuple
my_tuple = (1, 2, 3)
print(my_tuple)
# Out:
# (1, 2, 3)

# %%
type(my_tuple)
type(list1)
# Out:
# list

# %%
#Slice
print(list1[-2:-3])  # Output: [2, 3, 4]
# Out:
# []

# %%
## String Concatenation
first_name = "anuraag"
last_name = "narayan"

full_name = first_name + " " + last_name
print(full_name)
# Out:
# anuraag narayan

# %%
name = "Anuraag"
age = 25

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Anuraag and I am 25 years old.

# %%
name = "Anuraag"
print(name[0])
type(name)
# Out:
# A
# str
